# %%
# Import RDatasets.
using RDatasets
using Distributions
using Turing
using MCMCChain, Plots, StatPlots
using StatsFuns: logistic
using MLDataUtils

# Import the "Default" dataset.
data = RDatasets.dataset("ISLR", "Default");

# Show the first six rows of the dataset.
head(data)

# Create new rows, defualted to zero.
data[:DefaultNum] = 0.0
data[:StudentNum] = 0.0

for i in 1:length(data.Default)
    # If a row's "Default" or "Student" columns say "Yes",
    # set them to 1 in our new columns.
    data[:DefaultNum][i] = data.Default[i] == "Yes" ? 1.0 : 0.0
    data[:StudentNum][i] = data.Student[i] == "Yes" ? 1.0 : 0.0
end

# Delete the old columns which say "Yes" and "No".
delete!(data, :Default)
delete!(data, :Student)

# Show the first six rows of our edited dataset.
head(data)

# Split our dataset 70/30 into training/test sets.
train, test = MLDataUtils.splitobs(data, at = 0.7);

# Create our labels. These are the values we are trying to predict.
train_label = train[:DefaultNum]
test_label = test[:DefaultNum]

# Remove the columns that are not our predictors.
train = train[[:StudentNum, :Balance, :Income]]
test = test[[:StudentNum, :Balance, :Income]]

# Convert the DataFrame objects to matrices.
train = Matrix(train);
test = Matrix(test);

# Bayesian logistic regression (LR)
@model lr_nuts(x, y, d, n, σ²) = begin
    α ~ Normal(0, σ²)
    β ~ MvNormal(zeros(d), σ² * ones(d))
    for i = 1:n
        v = logistic(α + transpose(x[i,:]) * β)
        y[i] ~ Bernoulli(v)
    end
end

train = (train .- mean(train, dims=1)) ./ std(train, dims=1)

n, d = size(train)
chain = sample(lr_nuts(train, train_label, d, n, 1), NUTS(1000, 0.65))
describe(chain)
# Out:
# ┌ Info:  Assume - `α` is a parameter
# └ @ Turing /home/cameron/.julia/dev/Turing/src/core/compiler.jl:136
# ┌ Info:  Assume - `β` is a parameter
# └ @ Turing /home/cameron/.julia/dev/Turing/src/core/compiler.jl:136
# ┌ Info:  Observe - `y` is an observation
# └ @ Turing /home/cameron/.julia/dev/Turing/src/core/compiler.jl:154
# ┌ Warning: Requires now needs a UUID; please see the readme for changes in 0.7.
# └ @ Turing /home/cameron/.julia/dev/Turing/src/samplers/support/adapt.jl:60
# [Turing] looking for good initial eps...
# [NUTS{Any}] found initial ϵ: 0.0001953125
# [NUTS] Sampling...  0%  ETA: 5:18:57
#   ϵ:         0.0001953125
# [NUTS] Sampling...  0%  ETA: 2:06:18
#   ϵ:         0.010169026438440244
#   pre_cond:  [1.0, 1.0, 1.0, 1.0]┌ Warning: Numerical error has been found in gradients.
# └ @ Turing /home/cameron/.julia/dev/Turing/src/core/ad.jl:114
# ┌ Warning: grad = [Inf, Inf, Inf, -Inf]
# └ @ Turing /home/cameron/.julia/dev/Turing/src/core/ad.jl:115
# [NUTS] Sampling...  0%  ETA: 1:56:39
#   ϵ:         0.032051977487903255
# [NUTS] Sampling...  0%  ETA: 1:37:29
#   ϵ:         0.06623706349189343
#   pre_cond:  [1.0, 1.0, 1.0, 1.0]┌ Warning: Numerical error has been found in gradients.
# └ @ Turing /home/cameron/.julia/dev/Turing/src/core/ad.jl:114
# ┌ Warning: grad = [Inf, Inf, Inf, -Inf]
# └ @ Turing /home/cameron/.julia/dev/Turing/src/core/ad.jl:115
# [NUTS] Sampling...  1%  ETA: 1:26:02
#   ϵ:         0.03402748863364558
#   pre_cond:  [1.0, 1.0, 1.0, 1.0]┌ Warning: Numerical error has been found in gradients.
# └ @ Turing /home/cameron/.julia/dev/Turing/src/core/ad.jl:114
# ┌ Warning: grad = [Inf, NaN, Inf, NaN]
# └ @ Turing /home/cameron/.julia/dev/Turing/src/core/ad.jl:115
# [NUTS] Sampling...  1%  ETA: 1:02:18
#   ϵ:         0.04358416131820744
# [NUTS] Sampling...  1%  ETA: 0:58:49
#   ϵ:         0.1323964549047389
# [NUTS] Sampling...  1%  ETA: 1:07:34
#   ϵ:         0.050581541469522366
# [NUTS] Sampling...  1%  ETA: 1:04:29
#   ϵ:         0.10963084330401342
# [NUTS] Sampling...  2%  ETA: 0:59:51
#   ϵ:         0.04127393556833093
# [NUTS] Sampling...  2%  ETA: 0:59:11
#   ϵ:         0.11863129515587031
# [NUTS] Sampling...  2%  ETA: 0:58:44
#   ϵ:         0.03426448269369349
# [NUTS] Sampling...  2%  ETA: 0:56:44
#   ϵ:         0.07882598335309388
# [NUTS] Sampling...  2%  ETA: 0:54:55
#   ϵ:         0.13982827688688895
# [NUTS] Sampling...  2%  ETA: 0:53:19
#   ϵ:         0.042712810540168095
# [NUTS] Sampling...  2%  ETA: 0:52:59
#   ϵ:         0.11715338958400108
# [NUTS] Sampling...  2%  ETA: 0:52:45
#   ϵ:         0.01683593112156239
# [NUTS] Sampling...  2%  ETA: 0:59:43
#   ϵ:         0.04496481442324372
# [NUTS] Sampling...  3%  ETA: 0:57:15
#   ϵ:         0.01758175662859047
# [NUTS] Sampling...  3%  ETA: 0:55:53
#   ϵ:         0.043763024202066125
# [NUTS] Sampling...  3%  ETA: 0:53:58
#   ϵ:         0.018008359417916314
# [NUTS] Sampling...  3%  ETA: 0:53:46
#   ϵ:         0.0450353289694896
# [NUTS] Sampling...  3%  ETA: 0:53:48
#   ϵ:         0.017515501589782476
# [NUTS] Sampling...  3%  ETA: 0:55:29
#   ϵ:         0.04369924802991551
# [NUTS] Sampling...  3%  ETA: 0:54:28
#   ϵ:         0.1085577449084014
# [NUTS] Sampling...  4%  ETA: 0:53:26
#   ϵ:         0.026230388232733888
# [NUTS] Sampling...  4%  ETA: 0:53:15
#   ϵ:         0.06449286225949047
# [NUTS] Sampling...  4%  ETA: 0:53:24
#   ϵ:         0.028093969598620136
# [NUTS] Sampling...  4%  ETA: 0:54:08
#   ϵ:         0.06534301063882623
# [NUTS] Sampling...  4%  ETA: 0:53:15
#   ϵ:         0.045995358901550806
# [NUTS] Sampling...  4%  ETA: 0:54:25
#   ϵ:         0.022490276762145413
# [NUTS] Sampling...  4%  ETA: 0:54:18
#   ϵ:         0.05161262064418102
# [NUTS] Sampling...  4%  ETA: 0:56:58
#   ϵ:         0.0190940355897655
# [NUTS] Sampling...  4%  ETA: 0:56:07
#   ϵ:         0.038291760308479146
# [NUTS] Sampling...  5%  ETA: 0:58:27
#   ϵ:         0.02589772453037463
# [NUTS] Sampling...  5%  ETA: 0:57:39
#   ϵ:         0.058705954997471985
# [NUTS] Sampling...  5%  ETA: 0:58:33
#   ϵ:         0.05519616033156553
# [NUTS] Sampling...  5%  ETA: 0:58:28
#   ϵ:         0.018486469847697574
# [NUTS] Sampling...  5%  ETA: 0:59:17
#   ϵ:         0.041334579381660165
# [NUTS] Sampling...  5%  ETA: 0:58:34
#   ϵ:         0.07296898768994184
# [NUTS] Sampling...  6%  ETA: 0:59:30
#   ϵ:         0.02857341263107987
# [NUTS] Sampling...  6%  ETA: 0:58:44
#   ϵ:         0.061833745948672594
# [NUTS] Sampling...  6%  ETA: 0:59:03
#   ϵ:         0.04711513098868513
# [NUTS] Sampling...  6%  ETA: 0:58:19
#   ϵ:         0.07387142858624329
# [NUTS] Sampling...  6%  ETA: 0:56:17
#   ϵ:         0.05070844708345896
# [NUTS] Sampling...  6%  ETA: 0:55:54
#   ϵ:         0.06990804267535322
# [NUTS] Sampling...  6%  ETA: 0:56:42
#   ϵ:         0.05123035996435958
# [NUTS] Sampling...  6%  ETA: 0:56:06
#   ϵ:         0.05460829686423967
# [NUTS] Sampling...  6%  ETA: 0:55:55
#   ϵ:         0.07542827584162604
# [NUTS] Sampling...  7%  ETA: 0:56:15
#   ϵ:         0.05386404959557141
#   pre_cond:  [1.0, 1.0, 1.0, 1.0]
# InterruptException:
#
# Stacktrace:
#  [1] _forward at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/scalar.jl:55 [inlined]
#  [2] #track#1 at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/Tracker.jl:50 [inlined]
#  [3] track at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/Tracker.jl:50 [inlined]
#  [4] inv at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/scalar.jl:57 [inlined]
#  [5] #90 at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/scalar.jl:56 [inlined]
#  [6] back_(::Flux.Tracker.Grads, ::Flux.Tracker.Call{getfield(Flux.Tracker, Symbol("##90#91")){Flux.Tracker.TrackedReal{Float64}},Tuple{Flux.Tracker.Tracked{Float64}}}, ::Flux.Tracker.TrackedReal{Float64}) at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:103
#  [7] back(::Flux.Tracker.Grads, ::Flux.Tracker.Tracked{Float64}, ::Flux.Tracker.TrackedReal{Float64}) at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:118
#  [8] #4 at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:106 [inlined]
#  [9] foreach at ./abstractarray.jl:1836 [inlined]
#  [10] back_(::Flux.Tracker.Grads, ::Flux.Tracker.Call{getfield(Flux.Tracker, Symbol("##230#231")),Tuple{Nothing,Flux.Tracker.Tracked{Float64}}}, ::Flux.Tracker.TrackedReal{Float64}) at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:106
#  [11] back(::Flux.Tracker.Grads, ::Flux.Tracker.Tracked{Float64}, ::Flux.Tracker.TrackedReal{Float64}) at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:118
#  [12] (::getfield(Flux.Tracker, Symbol("##4#5")){Flux.Tracker.Grads})(::Flux.Tracker.Tracked{Float64}, ::Flux.Tracker.TrackedReal{Float64}) at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:106
#  [13] foreach at ./abstractarray.jl:1836 [inlined]
#  [14] back_(::Flux.Tracker.Grads, ::Flux.Tracker.Call{getfield(Flux.Tracker, Symbol("##104#105")){Flux.Tracker.TrackedReal{Float64}},Tuple{Flux.Tracker.Tracked{Float64}}}, ::Int64) at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:106
#  [15] back(::Flux.Tracker.Grads, ::Flux.Tracker.Tracked{Float64}, ::Int64) at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:118
#  [16] #4 at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:106 [inlined]
#  ... (the last 4 lines are repeated 4717 more times)
#  [18885] foreach at ./abstractarray.jl:1836 [inlined]
#  [18886] back_(::Flux.Tracker.Grads, ::Flux.Tracker.Call{getfield(Flux.Tracker, Symbol("##202#203")),Tuple{Flux.Tracker.Tracked{Float64},Flux.Tracker.Tracked{Float64}}}, ::Int64) at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:106
#  [18887] back(::Flux.Tracker.Grads, ::Flux.Tracker.Tracked{Float64}, ::Int64) at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:118
#  [18888] foreach at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:106 [inlined]
#  [18889] back_(::Flux.Tracker.Grads, ::Flux.Tracker.Call{getfield(Flux.Tracker, Symbol("##178#179")),Tuple{Flux.Tracker.Tracked{Float64}}}, ::Int64) at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:106
#  [18890] back(::Flux.Tracker.Grads, ::Flux.Tracker.Tracked{Float64}, ::Int64) at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:118
#  [18891] #6 at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:131 [inlined]
#  [18892] (::getfield(Flux.Tracker, Symbol("##9#11")){getfield(Flux.Tracker, Symbol("##6#7")){Flux.Tracker.Params,Flux.Tracker.TrackedReal{Float64}}})(::Int64) at /home/cameron/.julia/packages/Flux/UHjNa/src/tracker/back.jl:140
#  [18893] gradient_reverse(::SubArray{Real,1,Array{Real,1},Tuple{Array{Int64,1}},false}, ::Turing.VarReplay.VarInfo, ::Function, ::Turing.Sampler{NUTS{Any}}) at /home/cameron/.julia/dev/Turing/src/core/ad.jl:97
#  [18894] #_leapfrog#56(::Nothing, ::Nothing, ::Function, ::SubArray{Real,1,Array{Real,1},Tuple{Array{Int64,1}},false}, ::Array{Float64,1}, ::Int64, ::Float64, ::getfield(Turing, Symbol("##48#49")){Turing.VarReplay.VarInfo,Turing.Sampler{NUTS{Any}},typeof(lr_nuts_model)}) at /home/cameron/.julia/dev/Turing/src/core/ad.jl:23
#  [18895] _leapfrog at /home/cameron/.julia/dev/Turing/src/samplers/support/hmc_core.jl:93 [inlined]
#  [18896] #_build_tree#61(::Float64, ::Function, ::SubArray{Real,1,Array{Real,1},Tuple{Array{Int64,1}},false}, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Float64, ::Float64, ::getfield(Turing, Symbol("##50#51")){Turing.VarReplay.VarInfo,Turing.Sampler{NUTS{Any}},typeof(lr_nuts_model)}, ::getfield(Turing, Symbol("##48#49")){Turing.VarReplay.VarInfo,Turing.Sampler{NUTS{Any}},typeof(lr_nuts_model)}, ::Array{Float64,1}) at /home/cameron/.julia/dev/Turing/src/samplers/nuts.jl:143
#  [18897] _build_tree at /home/cameron/.julia/dev/Turing/src/samplers/nuts.jl:141 [inlined]
#  [18898] #_build_tree#61(::Float64, ::Function, ::SubArray{Real,1,Array{Real,1},Tuple{Array{Int64,1}},false}, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Float64, ::Float64, ::getfield(Turing, Symbol("##50#51")){Turing.VarReplay.VarInfo,Turing.Sampler{NUTS{Any}},typeof(lr_nuts_model)}, ::getfield(Turing, Symbol("##48#49")){Turing.VarReplay.VarInfo,Turing.Sampler{NUTS{Any}},typeof(lr_nuts_model)}, ::Array{Float64,1}) at /home/cameron/.julia/dev/Turing/src/samplers/nuts.jl:153
#  ... (the last 2 lines are repeated 1 more time)
#  [18901] _build_tree at /home/cameron/.julia/dev/Turing/src/samplers/nuts.jl:141 [inlined]
#  [18902] #_build_tree#61(::Float64, ::Function, ::SubArray{Real,1,Array{Real,1},Tuple{Array{Int64,1}},false}, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Float64, ::Float64, ::getfield(Turing, Symbol("##50#51")){Turing.VarReplay.VarInfo,Turing.Sampler{NUTS{Any}},typeof(lr_nuts_model)}, ::getfield(Turing, Symbol("##48#49")){Turing.VarReplay.VarInfo,Turing.Sampler{NUTS{Any}},typeof(lr_nuts_model)}, ::Array{Float64,1}) at /home/cameron/.julia/dev/Turing/src/samplers/nuts.jl:159
#  [18903] _build_tree(::SubArray{Real,1,Array{Real,1},Tuple{Array{Int64,1}},false}, ::Array{Float64,1}, ::Float64, ::Int64, ::Int64, ::Float64, ::Float64, ::Function, ::getfield(Turing, Symbol("##48#49")){Turing.VarReplay.VarInfo,Turing.Sampler{NUTS{Any}},typeof(lr_nuts_model)}, ::Array{Float64,1}) at /home/cameron/.julia/dev/Turing/src/samplers/nuts.jl:141
#  [18904] #_nuts_step#62(::Int64, ::Function, ::SubArray{Real,1,Array{Real,1},Tuple{Array{Int64,1}},false}, ::Float64, ::Function, ::Function, ::Array{Float64,1}) at /home/cameron/.julia/dev/Turing/src/samplers/nuts.jl:209
#  [18905] _nuts_step(::SubArray{Real,1,Array{Real,1},Tuple{Array{Int64,1}},false}, ::Float64, ::Function, ::Function, ::Array{Float64,1}) at /home/cameron/.julia/dev/Turing/src/samplers/nuts.jl:195
#  [18906] macro expansion at ./logging.jl:321 [inlined]
#  [18907] step(::Function, ::Turing.Sampler{NUTS{Any}}, ::Turing.VarReplay.VarInfo, ::Bool) at /home/cameron/.julia/dev/Turing/src/samplers/nuts.jl:68
#  [18908] macro expansion at ./logging.jl:309 [inlined]
#  [18909] #sample#63(::Int64, ::Bool, ::Nothing, ::Int64, ::Stan.Adapt, ::Function, ::Function, ::NUTS{Any}) at /home/cameron/.julia/dev/Turing/src/samplers/hmc.jl:147
#  [18910] sample(::Function, ::NUTS{Any}) at /home/cameron/.julia/dev/Turing/src/samplers/hmc.jl:105

# %%
plot(chain)
