# %% [markdown]
# # Model Comparison

# %% [markdown]
# This notebook is ported from [this](https://docs.pymc.io/notebooks/model_comparison.html) example notebook from PyMC3.
#
# Model Comparison refers to the task of comparing the predictions of different models that are available to us. It has useful applications. The results obtained after this comparison can be used to select the 'best' model. Alternatively, instead of selecting this 'best' model, we can use Model Averaging to obtain the weighted predictions from the models. These weights can be chosen based on the 'goodness' of each model.
#
# By the 'goodness' of a model, we are referring to how compatible it is to the data. For example, if we have a linear and a quadratic model, we ask the question: Which model best fits the data? Note that here, we cannot use the likelihood to compare the two models. The likelihood simply increases as you increase the complexity of the model. So, we need to find a technique that compares the two models while also accounting for overfitting when using complex models.
#
# We take a simple dataset which is the 8 schools example from Section 5.5 of Gelman et al (2003). This is an attempt to analyse the effect of coaching on the SAT scores of the students. We try two models: Pooled Model and Hierarchical Model. These are explained in some more detail below.
#
# Let's start with the usual routine: import the libraries.

# %%
#Import Turing, Distributions and LinearAlgebra 
using Turing, Distributions, LinearAlgebra

# Import MCMCChain, Plots, and StatsPlots for visualizations and diagnostics.
using MCMCChains, Plots, StatsPlots

# Set a seed for reproducibility.
using Random
Random.seed!(12);

# Turn off progress monitor.
Turing.turnprogress(false);
# Out:
# ┌ Info: [Turing]: global PROGRESS is set as false
# └ @ Turing /home/saumya/.julia/packages/Turing/r03H1/src/Turing.jl:24

# %% [markdown]
# # Loading The Data
#
# This data is from 8 schools each of which has about 60 students. In the below block, `y` denotes the estimated treatment effect of coaching and `sigma` denotes the standard deviation in the estimate of this effect.

# %%
J = 8
y = [28,  8, -3,  7, -1,  1, 18, 12]
sigma = [15, 10, 16, 11,  9, 11, 10, 18];

# %% [markdown]
# # Pooled Model
#
# We first take a pooled model where `y` is generated from a Gaussian. We already know the standard deviation of this distribution which is the corresponding entry in `sigma`. The mean of the Gaussian is the parameter $\Theta$ that we need to estimate. Note that in this model, we take a single mean $\mu$ for all the schools. The prior on the mean is also taken as a Gaussian. We take an uninformative prior with a high standard deviation, which is close to a uniform distribution. This effectively means that we are taking no assumption on the parametrization. Mathematically, the model is given by:
#
# Likelihood: $ p(y | \Theta) \sim N(\mu, \sigma) $
#
# where $ \Theta = [\mu] $
#
# Prior: $\Theta \sim N(0, 10^6)$

# %%
@model pooled_model(y, sigma, J) = begin
    mu ~ Normal(0, 1e6)
    for i = 1:J
        y[i] ~ Normal(mu, sigma[i])
    end
end;

# %% [markdown]
# Note how similar the model specifications are in Turing to the actual math. The flexibility provided in Turing makes specifying the model as easy as writing it on a piece of paper!

# %% [markdown]
# ## Sampling from the posterior
#
# We use the `NUTS` sampler to sample values from the posterior distribution $p(\Theta | y)$. We also remove the warmup samples by discarding the first 200 values. This number is specified in the second parameter of the `NUTS` sampler.

# %%
# This is temporary while the reverse differentiation backend is being improved.
Turing.setadbackend(:forward_diff)

# Sample using NUTS.
chain_pooled = sample(pooled_model(y, sigma, J), NUTS(1000, 200, 0.65))

# Remove the warmup samples
chain_pooled = chain_pooled[201:1000, :, :]
# Out:
# ┌ Info: [Turing] looking for good initial eps...
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/support/hmc_core.jl:240
# [NUTS{Turing.Core.ForwardDiffAD{40},Union{}}] found initial ϵ: 6.4
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/support/hmc_core.jl:235
# ┌ Warning: 120.93421495873957 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 172.5055540294431 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 156.60472556096468 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 445.7969834587392 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1342.9204474442015 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 4165.919809816427 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 13271.612008129292 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 23600.035453047334 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 73338.99300485148 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 224004.49369259353 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 540004.6921594494 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 627226.712024251 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.8044724505758502e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 659142.0182609984 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.8392475941148114e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 4.673883847294054e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.182392368182942e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.6335071835005265e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 4.233217924934306e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 7.642032186809069e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.467900983602058e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.06640550434122e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.211201175197355e8 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 4.2302467057668483e8 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.384112388683021e8 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.1578807628694763e9 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.2655414379178483e9 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.910474567395581e9 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.598671558725479e9 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.4755924707392458e10 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.102155696209577e10 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 5.94922679495421e10 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.2818845939322362e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.4445778539979828e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.055463906481677e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.006043301349495e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 5.732736471823712e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.310494938319211e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.8347250501388025e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.313110428399636e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.838186215753452e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.7788122914750566e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.552025479080191e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 7.028423164128189e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.3784644855108084e13 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.167629155027963e13 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 4.1861358181229055e13 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 7.415524030431142e13 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 8.224068932695577e13 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.036889452222947e13 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.7047635201058247e14 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.861743351626193e14 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 5.200690247506593e14 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 7.504859505884701e14 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.1334724420826835e15 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.072299381833955e15 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.3024488158392135e15 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 5.943087614347819e15 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.831177459559928e15 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.306264030952597e16 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.2765281930697482e16 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.264645788188193e16 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.994889750399753e16 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.925066645585896e16 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.2083811009710504e17 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.039771175732758e16 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.568299892246137e17 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.7069560020032278e17 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.2195748850799776e17 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 5.365535701306019e17 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.292980330559e17 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.44427284506364e17 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.5990205472731223e18 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.636362542159899e18 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.7528108888829327e18 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 4.610743898865757e18 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.360626912932217e18 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.0573478661247003e19 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.417104105819714e19 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.338942358035644e19 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.845130201117575e19 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 5.899253520181991e19 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.459457563960292e19 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.4223906121113056e20 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.060776341620148e20 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.329138730097588e20 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.020999956214196e20 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 4.858767742267867e20 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.4493496819081948e20 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.3325469370383768e20 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.7411142287040604e20 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 5.1426815252660696e20 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 5.988071835286109e20 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 7.520129175670032e20 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.1940127798622867e21 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.8898094087775631e21 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.8929425349690115e21 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 4.3480760140189286e21 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.639421357785157e21 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 31.889569007784385 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 38.67443644355326 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 20.338302106944585 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 41.23069765871129 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 93.21218469202985 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 137.26692835032466 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 303.36865884186363 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 337.8888624472503 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 316.43422451352126 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 959.5586419639617 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2888.993381267904 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 8592.696949974277 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 24015.38058908262 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 69138.41638509902 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 68958.34529264437 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 192548.15690342255 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 449848.04027964204 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 815120.8836762024 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 322856.3138316731 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 811047.25062455 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.1921507928164904e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 266078.21935590566 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 684084.6183975525 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.7291667088673864e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.234433123255598e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 7.777601540272183e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.992842401306817e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.6769071382270915e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.961873665045083e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.226299268194057e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.614810496642804e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.1924768331349212e8 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.6173197396409613e8 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 5.436295880717584e8 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.19965145984949e9 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.215053963382205e9 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.841816515887189e9 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 5.777358779498056e9 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.2242914734968801e10 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.249665448090212e10 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.330882829250768e10 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.8652493094355095e10 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.3581688604132018e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.1856239959096017e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.2574944445932086e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.283782566830736e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.241516086724584e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.96502533787436e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.823102445617127e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.616995842925577e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 94.47985543651536 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 247.37335382577874 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 310.7984032401728 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 819.3963055070449 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2494.452358963086 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 4837.516803240496 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 5223.342327207882 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 11831.297065947761 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 36687.904051587335 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 111989.15931616243 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 96593.35412721227 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 46355.34964674835 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 134757.44936164893 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 384299.66352751857 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 379274.7246624456 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 684713.055422187 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 485947.54902493744 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.307048078599492e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.2908616665006133e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.371283787401361e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 8.646202220384471e6 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.442584543851149e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.2588265617361747e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 7.970112221771386e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.866173247295198e7 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.64054929848034e8 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 3.860001274610219e8 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 7.672806151860409e8 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.1638927353598523e9 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.635167395956e9 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 5.886233583898811e9 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.503585046957819e9 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.2132858585082918e10 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.9666206443421642e10 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 4.21781301315553e10 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 8.828047526542654e10 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.601991990561886e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.2364325037962964e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.5598305902179163e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 4.6378181347937427e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.800308077569817e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 8.355589419587284e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.6746587116020964e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 9.496609569777393e11 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.2730054799012065e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.4579387505019062e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 4.405828885786954e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 6.690053059779376e12 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 1.2908614671487607e13 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Warning: 2.2835432666669734e13 exceeds 5.0; capped to 5.0 for numerical stability
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/stepsize.jl:96
# ┌ Info:  Adapted ϵ = 1.0, std = [1.0]; 200 iterations is used for adaption.
# └ @ Turing.Inference /home/saumya/.julia/packages/Turing/r03H1/src/inference/adapt/adapt.jl:91
# [NUTS] Finished with
#   Running time        = 3.801369174999994;
#   #lf / sample        = 0.0;
#   #evals / sample     = 22.18;
#   pre-cond. metric    = [1.0].
# Object of type Chains, with data of type 800×7×1 Array{Union{Missing, Float64},3}
#
# Log evidence      = 0.0
# Iterations        = 201:1000
# Thinning interval = 1
# Chains            = 1
# Samples per chain = 800
# internals         = elapsed, epsilon, eval_num, lf_eps, lf_num, lp
# parameters        = mu
#
# parameters
#     Mean    SD  Naive SE MCSE    ESS
# mu 8.2399 4.057   0.1434 0.33 151.1804

# %% [markdown]
# ## Visualising the posterior
#
# The `plot(chain_pooled)` allows us to view the following plots:
#
# - Plot of the sampled values vs the number of iterations. This helps us to visually identify whether the chain has converged.
# - Plot of the pdf of the sampled values. These sampled values are an approximation of our model's posterior.

# %%
plot(chain_pooled)

# %% [markdown]
# # Hierarchical Model
#
# Now, we will construct a hierarchical model. The hierarchical model allows for a random effect that partially pools the data. Each `y[i]` has common parameters $\mu$ and $\tau$. But it also has its own parameter $\eta[i]$. In this way, the groups are similar but also different!

# %%
@model hierarchical_model(y, sigma, J) = begin
    eta ~ MvNormal(J, 1)
    mu ~ Normal(0, 1e6)
    tau ~ Gamma(1, 1)
    for i = 1:J
        y[i] ~ Normal(mu + tau*eta[i], sigma[i])
    end
end;

# %% [markdown]
# ## Sampling from the posterior

# %%
# This is temporary while the reverse differentiation backend is being improved.
Turing.setadbackend(:forward_diff)

# Sample using NUTS.
chain_hierarchical = sample(hierarchical_model(y, sigma, J), NUTS(1000, 200, 0.65))

# Remove the warmup samples
chain_hierarchical = chain_hierarchical[201:1000, :, :]

# %%
plot(chain_hierarchical)

# %% [markdown]
# # Model Comparison with WAIC
#
# The code block below manually calculates the WAIC. This is likely to be temporary until `MCMCChains` supports these functions natively.
#
# The [WAIC Criterion](http://www.jmlr.org/papers/volume11/watanabe10a/watanabe10a.pdf) (Watanabe, Sumio (2010)) is a way to measure the fit of Bayesian models. Lower the WAIC value, the better the fit of the model. This criterion requires the following things:
#
# - The data `y`
# - Samples from the posterior distribution
# - The likelihood pdf
#
# The equation for WAIC is given by:
#
# $$ WAIC = -2 * (LPPPD - p_{waic})$$
#
# Here, LPPPD is the log pointwise posterior predictive density and $p_{waic}$ is the correction for effective number of parameters to adjust for overfitting. As compared to other Information Criteria, WAIC is more 'Bayesian' as it averages over the posterior distribution rather than using just a point estimate.
#
# Below, we calculate the WAIC values for each of the two models individually.

# %% [markdown]
# ## Pooled Model

# %%
lpppd = 0.0
p_pooled = 0.0

#Looping over all observations
for i = 1:J
    likelihood = Float64[]
    
    # Computing the likelihood for each point in the posterior
    for mu_value in chain_pooled[:mu] 
        dist = Normal(mu_value, sigma[i])
        push!(likelihood, pdf(dist, y[i]) )
    end
    
    # Adding the contribution of the current observation in lpppd
    log_mean = log(mean(likelihood))
    lpppd += log_mean
    
    #Calculating the p_waic value
    log_likelihood = log.(likelihood)
    var_likelihood = var(log_likelihood)
    p_pooled += var_likelihood
end

#Applying the above mentioned equation to get the final WAIC value
waic_pooled = -2*(lpppd - p_pooled);

# %%
waic_pooled, p_pooled

# %% [markdown]
# ## Hierarchical Model

# %%
sampling_size = 800
lpppd = 0.0
p_hierarchical = 0.0
for i = 1:J
    likelihood = Float64[]
    
    # Computing the likelihood for each point in the posterior
    # Note that here, we have to take the value of eta corresponding to the observation in the outer loop 
    # Looping over all the samples
    for sample = 1:sampling_size
        mu_value = chain_hierarchical[:mu][sample] 
        eta_value = chain_hierarchical[:eta][sample,i,:]
        tau_value = chain_hierarchical[:tau][sample] 
        dist = Normal(mu_value + eta_value[1]*tau_value, sigma[i])
        push!(likelihood, pdf(dist, y[i]) )
    end
    
    # Adding the contribution of the current observation in lpppd
    log_mean = log(mean(likelihood))
    lpppd += log_mean
    
    #Calculating the p_waic value
    log_likelihood = log.(likelihood)
    var_likelihood = var(log_likelihood)
    p_hierarchical += var_likelihood
end

#Applying the above mentioned equation to get the final WAIC value
waic_hierarchical = -2*(lpppd - p_hierarchical);

# %%
waic_hierarchical, p_hierarchical

# %% [markdown]
# # Interpretation
#
# Since the hierarchical model seems to be more complex and flexible, one might expect it to fit better on our data. It does have higher complexity which can be seen by comparing the p_waic values for both the models.

# %%
p_pooled, p_hierarchical

# %% [markdown]
# So, we get:
#
# `p_hierarchical` > `p_pooled`
#
# However, when it comes to deciding which model better fits the data ('goodness' of the model, as discussed earlier), we can see that the computed `waic` values for the models are approximately equal.

# %%
waic_pooled, waic_hierarchical

# %% [markdown]
# This means that both models are equally compatible with our data. Hence, we may be tempted to use the more complex model but this example shows that the simpler pooled model compares equally well.
